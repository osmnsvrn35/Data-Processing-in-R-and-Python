# %% [markdown]
# # Homework Assignment No.3
# # Yusif ALAKBARZADE 317297, Osman Can SAVRAN 317199

# %% [markdown]
# ## Reading The Data and Importing the libraries

# %%
import pandas as pd
from main import *
from create_graph import *

# %%
german_users = pd.read_xml('./stackexchange_data/G_Users.xml')
english_users = pd.read_xml('./stackexchange_data/E_Users.xml')
spanish_users = pd.read_xml('./stackexchange_data/S_Users.xml')
german_posts = pd.read_xml('./stackexchange_data/G_Posts.xml')
english_posts = pd.read_xml('./stackexchange_data/E_Posts.xml') 
spanish_posts = pd.read_xml('./stackexchange_data/S_Posts.xml')
english_comments = pd.read_xml('./stackexchange_data/E_Comments.xml') 
german_comments = pd.read_xml('./stackexchange_data/G_Comments.xml') 
spanish_comments = pd.read_xml('./stackexchange_data/S_Comments.xml')

# %% [markdown]
# # Question 1

# %% [markdown]
# In this section, we aim to explore the countries where the majority of questions are being asked.

# %%
resGER = questions_1(german_users,german_posts)
resSP = questions_1(spanish_users,spanish_posts)
resEN = questions_1(english_users,english_posts)
plot_location_count(resEN,resGER,resSP)

# %% [markdown]
# # Question 2

# %% [markdown]
# In this part our aim is the investigate if there is a correlation between user reputation and their engagement through comments and answers given by the user

# %% [markdown]
# # REPUTATION - COMMENT COUNT GRAPHS

# %%
resGER = questions_2(german_users,german_comments,german_posts)
resSP = questions_2(spanish_users,spanish_comments,spanish_posts)
resEN = questions_2(english_users,english_comments,english_posts)
plot_reputation_comments_count(resEN,resGER,resSP)

# %% [markdown]
# # REPUTATION - ANSWERS COUNT GRAPHS

# %%
plot_answers_comments_count(resEN,resGER,resSP)
